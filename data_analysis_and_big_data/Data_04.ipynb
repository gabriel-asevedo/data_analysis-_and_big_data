# %%
import pandas as pd

products = pd.read_excel('/content/Produtos.xlsx')

experimental_data = pd.read_csv('/content/dados_experimentos.csv')

# %%
products
# Out:
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar        5          4999.95    1.40
# 1   Carro Renault         4500.00   Euro        6         27000.00    2.00
# 2   Notebook Dell          899.99  Dólar        5          4499.95    1.70
# 3          IPhone          799.00  Dólar        5          3995.00    1.70
# 4      Carro Fiat         3000.00   Euro        6         18000.00    1.90
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40    2.00
# 6        Joia 20g           20.00   Ouro      350          7000.00    1.15
#
#    Preço de Venda
# 0        6999.930
# 1       54000.000
# 2        7649.915
# 3        6791.500
# 4       34200.000
# 5        4804.800
# 6        8050.000

# %%
products.describe()
# Out:
#        Preço Original     Cotação  Preço de Compra    Margem  Preço de Venda
# count        7.000000    7.000000         7.000000  7.000000        7.000000
# mean      1528.494286   54.571429      9699.614286  1.692857    17499.449286
# std       1611.187996  130.272608      9223.186179  0.319412    19076.854290
# min         20.000000    5.000000      2402.400000  1.150000     4804.800000
# 25%        639.740000    5.000000      4247.475000  1.550000     6895.715000
# 50%        899.990000    5.000000      4999.950000  1.700000     7649.915000
# 75%       1999.995000    6.000000     12500.000000  1.950000    21125.000000
# max       4500.000000  350.000000     27000.000000  2.000000    54000.000000

# %%
products['Moeda'].value_counts()
# Out:
# Dólar    4
# Euro     2
# Ouro     1
# Name: Moeda, dtype: int64

# %%
products[(products.Moeda == 'Dólar')]
# Out:
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar        5          4999.95     1.4
# 2   Notebook Dell          899.99  Dólar        5          4499.95     1.7
# 3          IPhone          799.00  Dólar        5          3995.00     1.7
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40     2.0
#
#    Preço de Venda
# 0        6999.930
# 2        7649.915
# 3        6791.500
# 5        4804.800

# %%
products.sort_values(by='Preço de Compra', ascending = True)
# Out:
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40    2.00
# 3          IPhone          799.00  Dólar        5          3995.00    1.70
# 2   Notebook Dell          899.99  Dólar        5          4499.95    1.70
# 0    Câmera Canon          999.99  Dólar        5          4999.95    1.40
# 6        Joia 20g           20.00   Ouro      350          7000.00    1.15
# 4      Carro Fiat         3000.00   Euro        6         18000.00    1.90
# 1   Carro Renault         4500.00   Euro        6         27000.00    2.00
#
#    Preço de Venda
# 5        4804.800
# 3        6791.500
# 2        7649.915
# 0        6999.930
# 6        8050.000
# 4       34200.000
# 1       54000.000

# %%
experimental_data.describe()
# Out:
#              tempo          g-0          g-1          g-2          g-3  \
# count  4504.000000  4504.000000  4504.000000  4504.000000  4504.000000
# mean     47.893428     0.218158    -0.112180     0.148899     0.073595
# std      19.418580     1.348012     0.814362     1.043202     0.954033
# min      24.000000    -5.513000    -5.737000    -4.958000    -5.998000
# 25%      24.000000    -0.473325    -0.557350    -0.447950    -0.435100
# 50%      48.000000    -0.017700    -0.062800     0.080950    -0.003400
# 75%      72.000000     0.498475     0.382725     0.655125     0.446975
# max      72.000000    10.000000     5.033000     8.257000     8.941000
#
#                g-4          g-5          g-6          g-7          g-8  ...  \
# count  4504.000000  4504.000000  4504.000000  4504.000000  4504.000000  ...
# mean      0.048719    -0.156363     0.052846    -0.208898    -0.171253  ...
# std       1.038948     1.166842     0.871327     1.128650     1.728461  ...
# min      -5.869000    -7.505000    -5.401000    -8.821000   -10.000000  ...
# 25%      -0.481200    -0.622900    -0.487850    -0.528200    -0.504650  ...
# 50%      -0.029450    -0.012650     0.012700    -0.036700     0.040050  ...
# 75%       0.457050     0.498925     0.545100     0.405525     0.557900  ...
# max       7.038000     5.322000     5.392000     5.261000     8.887000  ...
#
#               c-90         c-91         c-92         c-93         c-94  \
# count  4503.000000  4503.000000  4503.000000  4503.000000  4503.000000
# mean     -0.461899    -0.444674    -0.493078    -0.458254    -0.469709
# std       2.010769     2.045713     1.974611     2.078974     2.121307
# min     -10.000000   -10.000000   -10.000000   -10.000000   -10.000000
# 25%      -0.572600    -0.559150    -0.584450    -0.524450    -0.579000
# 50%      -0.008600     0.016400    -0.009600    -0.002200     0.015000
# 75%       0.449000     0.463300     0.455150     0.467650     0.489100
# max       4.069000     3.858000     3.841000     2.724000     3.747000
#
#               c-95         c-96         c-97         c-98         c-99
# count  4503.000000  4503.000000  4503.000000  4503.000000  4503.000000
# mean     -0.342108    -0.459590    -0.352481    -0.445987    -0.289134
# std       1.657489     2.074922     1.715941     1.826539     1.401360
# min     -10.000000   -10.000000   -10.000000   -10.000000   -10.000000
# 25%      -0.537300    -0.545150    -0.533950    -0.559450    -0.563550
# 50%       0.002700    -0.010900     0.001000     0.022300    -0.013000
# 75%       0.454150     0.476000     0.452900     0.458700     0.442200
# max       2.297000     3.167000     2.924000     2.441000     2.634000
#
# [8 rows x 873 columns]

# %%
experimental_data.sort_values('tratamento')
# Out:
#                 id    tratamento  tempo dose      droga     g-0     g-1  \
# 1170  id_0c09178e8  com_controle     72   D1  cacb2b860 -1.3260 -0.5058
# 613   id_064901c0f  com_controle     24   D1  cacb2b860 -1.8950 -1.3340
# 2813  id_1e40a37a2  com_controle     72   D2  cacb2b860  0.6156 -0.8491
# 3946  id_2a355b35b  com_controle     72   D1  cacb2b860 -1.2050  0.1442
# 3947  id_2a35d8e28  com_controle     48   D1  cacb2b860 -1.0360 -1.7910
# ...            ...           ...    ...  ...        ...     ...     ...
# 1568  id_10ac4bee0     com_droga     24   D2  87d714366  3.4660  0.9704
# 1569  id_10b32e960     com_droga     48   D2  c95ce9c16  4.5490 -0.1047
# 1570  id_10b859fb6     com_droga     72   D1  8f14abc3f  1.4610 -1.1170
# 1555  id_109bc1ca1     com_droga     72   D2  9a6b15c7b  0.2056 -1.1350
# 4503  id_307ec3342     com_droga     24   D1  7fbcc1553  0.6593  0.3433
#
#          g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 1170 -0.3619  0.7520  0.1094  ... -1.1270 -0.8153 -1.9340  0.2021 -3.0710
# 613  -0.0619  0.9232 -1.3780  ...  0.6599  0.9685  0.4651  0.2810  0.9772
# 2813 -0.5525 -0.5020 -0.4498  ...  0.4172  0.1386  0.5771  0.0147  0.9969
# 3946 -0.5151 -0.7612 -1.1250  ...  1.0080  0.3410  0.5967  0.9650  1.2470
# 3947 -0.7911  0.0708 -2.3410  ...  0.4457 -1.3440  0.6974  1.2360  1.4310
# ...      ...     ...     ...  ...     ...     ...     ...     ...     ...
# 1568  2.0000  3.0450  1.0080  ... -9.6980 -9.2360 -5.4040 -8.3400 -7.2930
# 1569  2.5780 -3.6130 -0.4000  ...  1.1240  1.4000 -0.7940  0.7075  0.6641
# 1570 -0.5845  0.6306  0.6962  ... -0.7554 -0.7850 -0.3856  0.1576 -0.8304
# 1555 -0.0337 -0.1151 -0.6792  ...  0.3160  0.2328  0.9694  1.3880  1.4600
# 4503 -0.5412 -0.1518  0.3231  ...     NaN     NaN     NaN     NaN     NaN
#
#         c-95    c-96    c-97    c-98    c-99
# 1170 -2.3270 -2.9270 -3.1580 -1.7210 -2.5420
# 613  -0.0826  0.2617 -0.6966  0.6229  0.2291
# 2813  0.1841  0.9013  0.2793  0.8297  0.0269
# 3946  1.3340  0.5028  0.7684  0.9824  1.4990
# 3947  1.2840  1.2550  0.7903 -0.2257 -0.2506
# ...      ...     ...     ...     ...     ...
# 1568 -2.3300 -7.7640 -6.4610 -4.5750 -3.7550
# 1569  0.4779  1.8420 -1.1020 -2.3730  1.0580
# 1570 -0.6987  0.3544  0.0788 -0.6927 -0.8078
# 1555  1.3330  0.9980 -0.1401  0.0723  0.2745
# 4503     NaN     NaN     NaN     NaN     NaN
#
# [4504 rows x 877 columns]

# %%
experimental_data.sort_values(by='dose')
# Out:
#                 id    tratamento  tempo dose      droga     g-0     g-1  \
# 0     id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 2471  id_1a5764352  com_controle     72   D1  cacb2b860 -0.2304 -0.9389
# 2476  id_1a601b06b     com_droga     48   D1  1a30dbdd2 -0.4021 -0.0838
# 2477  id_1a6122127     com_droga     24   D1  233bbbb62 -0.0761 -0.6288
# 2482  id_1a743ac8e     com_droga     48   D1  288928fcc  0.7068  0.3966
# ...            ...           ...    ...  ...        ...     ...     ...
# 893   id_090cc7901     com_droga     72   D2  07ab9d694 -0.1481  1.0340
# 2648  id_1c3dc668f     com_droga     24   D2  dd73b5345  0.0506  0.3364
# 892   id_090a5343d     com_droga     72   D2  4da81d116 -0.0909 -0.0532
# 2678  id_1ca2b3c6d     com_droga     24   D2  4c57ebd49 -0.0700 -0.7224
# 2251  id_1820b3123     com_droga     24   D2  5842b3aff -1.2210 -0.8825
#
#          g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 0    -0.2479 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912
# 2471  0.5376 -0.1167 -1.4330  ...  0.1256  0.0778  0.6268  0.7838  0.3635
# 2476  0.8101 -0.8779 -0.4144  ...  1.1830  1.2460 -0.5289 -0.0237  0.4600
# 2477  2.4790  0.0506  1.7270  ...  0.3609  0.1954  0.0585 -0.1012 -0.0014
# 2482  0.3837 -1.3240 -0.1612  ... -0.4179 -0.3203  0.0584 -0.0580 -1.0920
# ...      ...     ...     ...  ...     ...     ...     ...     ...     ...
# 893  -0.8829 -0.2966 -0.1284  ...  0.6243  0.5128 -0.6933  1.9700  0.8032
# 2648  0.4711  0.3173  0.3051  ...  0.0329  0.2759 -0.2543 -1.3090  0.0891
# 892   0.1353 -0.3118  0.4204  ... -0.1911 -0.4187 -1.1440 -0.0733  0.1769
# 2678  1.4630  2.3220 -1.8880  ...  0.7168  1.3840  0.5675  0.4500  0.9386
# 2251 -0.7442 -0.7772 -0.9675  ...  0.5666  1.1420  0.6767 -0.0344  0.3539
#
#         c-95    c-96    c-97    c-98    c-99
# 0     0.6584 -0.3981  0.2139  0.3801  0.4176
# 2471  0.0086 -0.0191  0.0681  0.2517  0.3258
# 2476 -0.3480  0.6629  0.2775  1.2050 -1.1570
# 2477 -0.8444  0.1505 -0.1452 -0.6018 -0.7211
# 2482 -0.5828 -0.6514 -0.4074 -0.6211  0.1789
# ...      ...     ...     ...     ...     ...
# 893   0.4880  0.8232 -0.0629  1.2430 -0.0386
# 2648 -0.0872  1.1550  0.3627 -0.2244 -0.6345
# 892   0.6122  0.7038  0.0015 -0.9556 -0.1771
# 2678  1.0240 -0.0476  1.7020 -0.7078  0.0762
# 2251  0.9039  0.8283 -0.7239 -0.5443  0.7020
#
# [4504 rows x 877 columns]

# %%
experimental_data['tratamento'].value_counts()
# Out:
# com_droga       4159
# com_controle     345
# Name: tratamento, dtype: int64

# %%
experimental_data['droga'].value_counts()
# Out:
# cacb2b860    345
# 87d714366    147
# 9f80f3f77     51
# d50f18348     40
# 8b87a7a83     33
#             ...
# 366bf0132      1
# a19d26516      1
# 601af9b8d      1
# b0fbaa16b      1
# 63425c3b3      1
# Name: droga, Length: 2321, dtype: int64

# %%
# products
#O documento examinado contém dados sobre produtos importados, incluindo informações como nome, preço e a moeda de compra.
#Ele realiza cálculos para determinar o gasto em moeda local (real) e, em seguida, multiplica esse valor pela "Margem" para estabelecer o preço de venda, levando em consideração o lucro incorporado na margem.
#Parece ser uma tabela relacionada a uma loja que se dedica à importação e venda de itens, pois exibe valores originais em sua moeda nativa e a margem de lucro ao converter para a moeda local (real) para a venda.

# %%
# experimental_data
#Os registros experimentais fornecem informações sobre os procedimentos realizados em um contexto médico, possivelmente relacionados a uma condição específica.
#A tabela apresenta dados sobre a dose administrada (seja primeira, segunda, etc.) e um identificador que provavelmente referencia o nome da droga em outra tabela.
#Esse arquivo parece trazer informações sobre experimentos relacionados a uma possível doença, incluindo identificação, tratamento, tempo de tratamento, doses necessárias e identificação da droga utilizada.
